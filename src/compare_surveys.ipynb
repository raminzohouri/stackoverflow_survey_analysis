# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(20,10)})
import data_utils as t
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df20 = pd.read_csv('../data/survey_results_public_2020.csv')
schema20 = pd.read_csv('../data/survey_results_schema_2020.csv')
df20['HigherEd'] = df20.EdLevel.apply(t.higher_ed) 
df20['JobSatisfied'] = df20.JobSat.apply(t.job_satisfaction)
df19 = pd.read_csv('../data/survey_results_public_2019.csv')
schema19 = pd.read_csv('../data/survey_results_schema_2019.csv')
df19['HigherEd'] = df19.EdLevel.apply(t.higher_ed) 
df19['JobSatisfied'] = df19.JobSat.apply(t.job_satisfaction)

# %%
shared_field_20_19 = set(schema20.Column).intersection(set(schema19.Column));
shared_field_20_19
# Out:
# {'Age',
#  'Age1stCode',
#  'CompFreq',
#  'CompTotal',
#  'ConvertedComp',
#  'Country',
#  'CurrencyDesc',
#  'CurrencySymbol',
#  'DatabaseDesireNextYear',
#  'DatabaseWorkedWith',
#  'DevType',
#  'EdLevel',
#  'Employment',
#  'Ethnicity',
#  'Gender',
#  'Hobbyist',
#  'JobFactors',
#  'JobSat',
#  'JobSeek',
#  'LanguageDesireNextYear',
#  'LanguageWorkedWith',
#  'MainBranch',
#  'MiscTechDesireNextYear',
#  'MiscTechWorkedWith',
#  'OpSys',
#  'OrgSize',
#  'PlatformDesireNextYear',
#  'PlatformWorkedWith',
#  'PurchaseWhat',
#  'Respondent',
#  'SOAccount',
#  'SOComm',
#  'SOPartFreq',
#  'SOVisitFreq',
#  'Sexuality',
#  'SurveyEase',
#  'SurveyLength',
#  'Trans',
#  'UndergradMajor',
#  'WelcomeChange',
#  'WorkWeekHrs',
#  'YearsCode',
#  'YearsCodePro'}

# %%
LanguageWorkedWith19 = t.compare_multiple_choice_with_filter(df19, 'LanguageWorkedWith', 'JobSatisfied', [0,1])
LanguageDesireNextYear19 = t.compare_multiple_choice_with_filter(df19, 'LanguageDesireNextYear', 'JobSatisfied', [0,1])
LanguageWorkedWith20 = t.compare_multiple_choice_with_filter(df20, 'LanguageWorkedWith', 'JobSatisfied', [0,1])
LanguageDesireNextYear20 = t.compare_multiple_choice_with_filter(df20, 'LanguageDesireNextYear', 'JobSatisfied', [0,1])

# %%
LanguageWorkedWith19[['JobSatisfied_1_perc','JobSatisfied_0_perc']].plot(kind='bar', figsize=(20,10))
LanguageDesireNextYear19[['JobSatisfied_1_perc','JobSatisfied_0_perc']].plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='LanguageDesireNextYear'>

# %%
LanguageWorkedWith20[['JobSatisfied_1_perc','JobSatisfied_0_perc']].plot(kind='bar', figsize=(20,10))
LanguageDesireNextYear20[['JobSatisfied_1_perc','JobSatisfied_0_perc']].plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='LanguageDesireNextYear'>

# %%
d201 = t.get_multiple_choice_value_count(df20, 'LanguageWorkedWith', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d202 = t.get_multiple_choice_value_count(df20, 'LanguageDesireNextYear', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d201.drop('nan', inplace=True)
d202.drop('nan', inplace=True)
d191 = t.get_multiple_choice_value_count(df19, 'LanguageWorkedWith', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d192 = t.get_multiple_choice_value_count(df19, 'LanguageDesireNextYear', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d191.drop('nan', inplace=True)
d192.drop('nan', inplace=True)

# %%
d1_diff = d201-d191 
d1_diff.rename(columns={'MultiValues':'PercentageWorkedWith'},inplace=True)
d1_diff.plot(kind='bar',figsize=(20,10), title='Changes in using programming languages between 2019 and 2020');

# %%
(d202-d192).plot(kind='bar',figsize=(20,10));

# %%
d201 = t.get_multiple_choice_value_count(df20, 'MiscTechWorkedWith', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d202 = t.get_multiple_choice_value_count(df20, 'MiscTechDesireNextYear', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d191 = t.get_multiple_choice_value_count(df19, 'MiscTechWorkedWith', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d192 = t.get_multiple_choice_value_count(df19, 'MiscTechDesireNextYear', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d201.drop('nan', inplace=True)
d202.drop('nan', inplace=True)
d191.drop('nan', inplace=True)
d192.drop('nan', inplace=True)

# %%
d1_diff = d201-d191 
d1_diff.rename(columns={'MultiValues':'PercentageWorkedWith'},inplace=True)
d1_diff.plot(kind='bar',figsize=(20,10), title='Changes in using various technology between 2019 and 2020');

# %%
d201 = t.get_multiple_choice_value_count(df20, 'DevType', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d202 = t.get_multiple_choice_value_count(df20, 'DevType', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d191 = t.get_multiple_choice_value_count(df19, 'DevType', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d192 = t.get_multiple_choice_value_count(df19, 'DevType', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d201.drop('nan', inplace=True)
d202.drop('nan', inplace=True)
d191.drop('nan', inplace=True)
d192.drop('nan', inplace=True)

# %%
d1_diff = d201-d191 
d1_diff.rename(columns={'MultiValues':'PercentageWorkedWith'},inplace=True)
d1_diff.plot(kind='bar',figsize=(20,10), title='Changes in using various type of developers between 2019 and 2020');

# %%
d201 = t.get_multiple_choice_value_count(df20, 'DatabaseWorkedWith', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d202 = t.get_multiple_choice_value_count(df20, 'DatabaseDesireNextYear', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d191 = t.get_multiple_choice_value_count(df19, 'DatabaseWorkedWith', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 
d192 = t.get_multiple_choice_value_count(df19, 'DatabaseDesireNextYear', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d201.drop('nan', inplace=True)
d202.drop('nan', inplace=True)
d191.drop('nan', inplace=True)
d192.drop('nan', inplace=True)

# %%
d1_diff = d201-d191 
d1_diff.rename(columns={'MultiValues':'PercentageWorkedWith'},inplace=True)
d1_diff.plot(kind='bar',figsize=(20,10), title='Changes in using various type of database between 2019 and 2020');

# %%
d201 = t.get_multiple_choice_value_count(df20, 'OrgSize', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True)  

d191 = t.get_multiple_choice_value_count(df19, 'OrgSize', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True)  

d201.drop('nan', inplace=True)
d191.drop('nan', inplace=True)
d1_diff = d201-d191 
d1_diff.rename(columns={'MultiValues':'PercentageWorkedWith'},inplace=True)
d1_diff.plot(kind='bar',figsize=(20,10), title='Changes in using various type of database between 2019 and 2020');

# %%
c, n = t.categorize_values_in_range(df19, 'ConvertedComp', 20);
df19[n]=c;
comp_df19 =t.compare_multiple_choice_with_filter(df19, n, 'HigherEd', [0,1])
c, n = t.categorize_values_in_range(df20, 'ConvertedComp', 20);
df20[n]=c;
comp_df20 =t.compare_multiple_choice_with_filter(df20, n, 'HigherEd', [0,1])
comp_df = t.compare_categorical_dataframes(comp_df20.HigherEd_1_perc, comp_df19.HigherEd_1_perc,'2020_HigherEd_1_perc','2019_HigherEd_1_perc')
comp_df.style.bar(subset=[comp_df.columns[-1]], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.5%, #5fba7d 38.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.4%, #d65f5f 35.4%, #d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row3_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.9%, #d65f5f 36.9%, #d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row5_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.9%, #d65f5f 36.9%, #d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.9%, #d65f5f 36.9%, #d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.4%, #d65f5f 35.4%, #d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.8%, #d65f5f 33.8%, #d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row10_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row11_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row12_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.9%, #d65f5f 36.9%, #d65f5f 38.5%, transparent 38.5%);
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row14_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row15_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row16_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row17_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row18_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.8%, #d65f5f 33.8%, #d65f5f 38.5%, transparent 38.5%);
#         }</style><table id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2020_HigherEd_1_perc</th>        <th class="col_heading level0 col1" >2019_HigherEd_1_perc</th>        <th class="col_heading level0 col2" >Diff_Vals</th>    </tr>    <tr>        <th class="index_name level0" >ConvertedCompCategorized</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row0" class="row_heading level0 row0" >49000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row0_col0" class="data row0 col0" >0.509000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row0_col1" class="data row0 col1" >0.534000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row0_col2" class="data row0 col2" >-0.025000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row1" class="row_heading level0 row1" >150000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row1_col0" class="data row1 col0" >0.447000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row1_col1" class="data row1 col1" >0.407000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row1_col2" class="data row1 col2" >0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row2" class="row_heading level0 row2" >250000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row2_col0" class="data row2 col0" >0.013000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row2_col1" class="data row2 col1" >0.015000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row2_col2" class="data row2 col2" >-0.002000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row3" class="row_heading level0 row3" >350000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row3_col0" class="data row3 col0" >0.005000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row3_col1" class="data row3 col1" >0.005000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row3_col2" class="data row3 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row4" class="row_heading level0 row4" >450000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row4_col0" class="data row4 col0" >0.003000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row4_col1" class="data row4 col1" >0.004000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row4_col2" class="data row4 col2" >-0.001000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row5" class="row_heading level0 row5" >550000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row5_col0" class="data row5 col0" >0.004000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row5_col1" class="data row5 col1" >0.004000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row5_col2" class="data row5 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row6" class="row_heading level0 row6" >650000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row6_col0" class="data row6 col0" >0.003000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row6_col1" class="data row6 col1" >0.004000</td>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row6_col2" class="data row6 col2" >-0.001000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226level0_row7" class="row_heading level0 row7" >750000.0</th>
#                         <td id="T_cc1173f6_ebb7_11ea_93e0_8416f9fed226row7_col0" class="data row7 col0" >0.003000</td>
#                         <td id="T_cc1173f

# %%
c, n = t.categorize_values_in_range(df19, 'ConvertedComp', 20);
df19[n]=c;
comp_df19 =t.compare_multiple_choice_with_filter(df19, n, 'HigherEd', [0,1])
c, n = t.categorize_values_in_range(df20, 'ConvertedComp', 20);
df20[n]=c;
comp_df20 =t.compare_multiple_choice_with_filter(df20, n, 'HigherEd', [0,1])
comp_df = t.compare_categorical_dataframes(comp_df20.HigherEd_0_perc, comp_df19.HigherEd_0_perc,'2020_HigherEd_0_perc','2019_HigherEd_0_perc')
comp_df.style.bar(subset=[comp_df.columns[-1]], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.7%, #5fba7d 43.7%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.4%, #d65f5f 42.4%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.7%, #d65f5f 41.7%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row12_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row14_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row15_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row16_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row17_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, #d65f5f 43.1%, #d65f5f 43.7%, transparent 43.7%);
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row18_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_929a2eae_ebbe_11ea_93e0_8416f9fed226row19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.0%, #d65f5f 41.0%, #d65f5f 43.7%, transparent 43.7%);
#         }</style><table id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2020_HigherEd_0_perc</th>        <th class="col_heading level0 col1" >2019_HigherEd_0_perc</th>        <th class="col_heading level0 col2" >Diff_Vals</th>    </tr>    <tr>        <th class="index_name level0" >ConvertedCompCategorized</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226level0_row0" class="row_heading level0 row0" >49000.0</th>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row0_col0" class="data row0 col0" >0.391000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row0_col1" class="data row0 col1" >0.454000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row0_col2" class="data row0 col2" >-0.063000</td>
#             </tr>
#             <tr>
#                         <th id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226level0_row1" class="row_heading level0 row1" >150000.0</th>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row1_col0" class="data row1 col0" >0.575000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row1_col1" class="data row1 col1" >0.494000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row1_col2" class="data row1 col2" >0.081000</td>
#             </tr>
#             <tr>
#                         <th id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226level0_row2" class="row_heading level0 row2" >250000.0</th>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row2_col0" class="data row2 col0" >0.010000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row2_col1" class="data row2 col1" >0.011000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row2_col2" class="data row2 col2" >-0.001000</td>
#             </tr>
#             <tr>
#                         <th id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226level0_row3" class="row_heading level0 row3" >350000.0</th>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row3_col0" class="data row3 col0" >0.003000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row3_col1" class="data row3 col1" >0.004000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row3_col2" class="data row3 col2" >-0.001000</td>
#             </tr>
#             <tr>
#                         <th id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226level0_row4" class="row_heading level0 row4" >450000.0</th>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row4_col0" class="data row4 col0" >0.002000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row4_col1" class="data row4 col1" >0.003000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row4_col2" class="data row4 col2" >-0.001000</td>
#             </tr>
#             <tr>
#                         <th id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226level0_row5" class="row_heading level0 row5" >550000.0</th>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row5_col0" class="data row5 col0" >0.002000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row5_col1" class="data row5 col1" >0.003000</td>
#                         <td id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226row5_col2" class="data row5 col2" >-0.001000</td>
#             </tr>
#             <tr>
#                         <th id="T_929a2eae_ebbe_11ea_93e0_8416f9fed226level0_row6" class="row_heading level0

# %%
d19=pd.DataFrame(df19.query("MainBranch == 'I am a developer by profession' and (Gender == 'Man' or Gender == 'Woman') and (YearsCodePro > '5' or YearsCodePro < '10')").groupby(['EdLevel']).mean()['ConvertedComp']).sort_index(axis=1,ascending=True)
d20=pd.DataFrame(df20.query("MainBranch == 'I am a developer by profession' and (Gender == 'Man' or Gender == 'Woman') and (YearsCodePro > '5' or YearsCodePro < '10')").groupby(['EdLevel']).mean()['ConvertedComp']).sort_index(axis=1,ascending=True)
comp_df=pd.merge(d20,d19,left_index=True, right_index=True)
ff_n_diff = 'Diff_Vals'
comp_df.columns = ['ConvertedComp_2020', 'ConvertedComp_2019']
comp_df[ff_n_diff] = comp_df['ConvertedComp_2020'] - comp_df['ConvertedComp_2019']
comp_df.style.bar(subset=[comp_df.columns[-1]], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 74.9%, transparent 74.9%);
#         }    #T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 74.9%, #5fba7d 74.9%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 74.9%, #5fba7d 74.9%, #5fba7d 83.4%, transparent 83.4%);
#         }    #T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 74.9%, #5fba7d 74.9%, #5fba7d 77.1%, transparent 77.1%);
#         }    #T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 58.7%, #d65f5f 58.7%, #d65f5f 74.9%, transparent 74.9%);
#         }</style><table id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ConvertedComp_2020</th>        <th class="col_heading level0 col1" >ConvertedComp_2019</th>        <th class="col_heading level0 col2" >Diff_Vals</th>    </tr>    <tr>        <th class="index_name level0" >EdLevel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226level0_row0" class="row_heading level0 row0" >I never completed any formal education</th>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row0_col0" class="data row0 col0" >47020.615385</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row0_col1" class="data row0 col1" >190605.166667</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row0_col2" class="data row0 col2" >-143584.551282</td>
#             </tr>
#             <tr>
#                         <th id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226level0_row1" class="row_heading level0 row1" >Primary/elementary school</th>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row1_col0" class="data row1 col0" >110352.941176</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row1_col1" class="data row1 col1" >62349.586667</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row1_col2" class="data row1 col2" >48003.354510</td>
#             </tr>
#             <tr>
#                         <th id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226level0_row2" class="row_heading level0 row2" >Professional degree (JD, MD, etc.)</th>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row2_col0" class="data row2 col0" >85814.242424</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row2_col1" class="data row2 col1" >69529.817204</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row2_col2" class="data row2 col2" >16284.425220</td>
#             </tr>
#             <tr>
#                         <th id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226level0_row3" class="row_heading level0 row3" >Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)</th>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row3_col0" class="data row3 col0" >59211.703209</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row3_col1" class="data row3 col1" >55124.087760</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row3_col2" class="data row3 col2" >4087.615449</td>
#             </tr>
#             <tr>
#                         <th id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226level0_row4" class="row_heading level0 row4" >Some college/university study without earning a degree</th>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row4_col0" class="data row4 col0" >68660.575693</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row4_col1" class="data row4 col1" >99804.391832</td>
#                         <td id="T_f77d5f1a_ebbb_11ea_93e0_8416f9fed226row4_col2" class="data row4 col2" >-31143.816139</td>
#             </tr>
#     </tbody></table>

# %%
d19=pd.DataFrame(df19.query("HigherEd == 1 and MainBranch == 'I am a developer by profession' and (Gender == 'Man' or Gender == 'Woman')").groupby(['Gender']).mean()['ConvertedComp']).sort_index(axis=1,ascending=True)
d20=pd.DataFrame(df20.query("HigherEd == 1 and MainBranch == 'I am a developer by profession' and (Gender == 'Man' or Gender == 'Woman')").groupby(['Gender']).mean()['ConvertedComp']).sort_index(axis=1,ascending=True)
comp_df=pd.merge(d20,d19,left_index=True, right_index=True)
ff_n_diff = 'Diff_Vals'
comp_df.columns = ['ConvertedComp_2020', 'ConvertedComp_2019']
comp_df[ff_n_diff] = comp_df['ConvertedComp_2020'] - comp_df['ConvertedComp_2019']
comp_df.style.bar(subset=[comp_df.columns[-1]], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 73.5%, #d65f5f 73.5%, #d65f5f 100.0%, transparent 100.0%);
#         }</style><table id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ConvertedComp_2020</th>        <th class="col_heading level0 col1" >ConvertedComp_2019</th>        <th class="col_heading level0 col2" >Diff_Vals</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226level0_row0" class="row_heading level0 row0" >Man</th>
#                         <td id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row0_col0" class="data row0 col0" >100972.192308</td>
#                         <td id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row0_col1" class="data row0 col1" >120049.052848</td>
#                         <td id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row0_col2" class="data row0 col2" >-19076.860541</td>
#             </tr>
#             <tr>
#                         <th id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226level0_row1" class="row_heading level0 row1" >Woman</th>
#                         <td id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row1_col0" class="data row1 col0" >94174.465580</td>
#                         <td id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row1_col1" class="data row1 col1" >99233.522388</td>
#                         <td id="T_0a8ffe6c_ebbe_11ea_93e0_8416f9fed226row1_col2" class="data row1 col2" >-5059.056808</td>
#             </tr>
#     </tbody></table>

# %%
comp_df20 = t.compare_multiple_choice_with_filter(df20, 'NEWJobHunt', 'HigherEd', [0,1])
comp_df20.style.bar(subset=[comp_df20.columns[-1]], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 85.3%, transparent 85.3%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 93.2%, transparent 93.2%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 87.9%, transparent 87.9%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 71.7%, transparent 71.7%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 64.5%, transparent 64.5%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 73.6%, transparent 73.6%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 75.6%, transparent 75.6%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 73.0%, transparent 73.0%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 68.7%, transparent 68.7%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 61.9%, transparent 61.9%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.6%, #5fba7d 60.6%, #5fba7d 93.5%, transparent 93.5%);
#         }    #T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.6%, transparent 60.6%);
#         }</style><table id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HigherEd_1_perc</th>        <th class="col_heading level0 col1" >HigherEd_0_perc</th>        <th class="col_heading level0 col2" >HigherEd_Diff_Vals</th>    </tr>    <tr>        <th class="index_name level0" >NEWJobHunt</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row0" class="row_heading level0 row0" >Better compensation</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row0_col0" class="data row0 col0" >0.554000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row0_col1" class="data row0 col1" >0.433000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row0_col2" class="data row0 col2" >0.121000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row1" class="row_heading level0 row1" >Better work/life balance</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row1_col0" class="data row1 col0" >0.376000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row1_col1" class="data row1 col1" >0.300000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row1_col2" class="data row1 col2" >0.076000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row2" class="row_heading level0 row2" >Curious about other opportunities</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row2_col0" class="data row2 col0" >0.453000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row2_col1" class="data row2 col1" >0.353000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row2_col2" class="data row2 col2" >0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row3" class="row_heading level0 row3" >Growth or leadership opportunities</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row3_col0" class="data row3 col0" >0.413000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row3_col1" class="data row3 col1" >0.329000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row3_col2" class="data row3 col2" >0.084000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row4" class="row_heading level0 row4" >Having a bad day (or week or month) at work</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row4_col0" class="data row4 col0" >0.160000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row4_col1" class="data row4 col1" >0.126000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row4_col2" class="data row4 col2" >0.034000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row5" class="row_heading level0 row5" >Just because</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row5_col0" class="data row5 col0" >0.090000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row5_col1" class="data row5 col1" >0.078000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row5_col2" class="data row5 col2" >0.012000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row6" class="row_heading level0 row6" >Looking to relocate</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row6_col0" class="data row6 col0" >0.204000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row6_col1" class="data row6 col1" >0.164000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row6_col2" class="data row6 col2" >0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row7" class="row_heading level0 row7" >Trouble with leadership at my company</th>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row7_col0" class="data row7 col0" >0.212000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row7_col1" class="data row7 col1" >0.166000</td>
#                         <td id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226row7_col2" class="data row7 col2" >0.046000</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f4e5c6_ebcd_11ea_93e0_8416f9fed226level0_row8" class="row_heading le

# %%
d201 = t.get_multiple_choice_value_count(df20, 'JobSeek', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True)  
d191 = t.get_multiple_choice_value_count(df19, 'JobSeek', do_norm=True, set_index=True,
                                           filter_condition={}, show_plot=True) 

d201.drop('nan', inplace=True)
d191.drop('nan', inplace=True)

# %%
d1_diff = d201-d191 
d1_diff.rename(columns={'MultiValues':'PercentageWorkedWith'},inplace=True)
d1_diff.plot(kind='bar',figsize=(20,10), title='Job Huntting  between 2019 and 2020');
